# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\msi\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\msi\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.3 is available.
# You should consider upgrading via the 'c:\Users\MSI\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# Mini projet
# nakia gaddour
# le data

# %%
# import des biblio
import pandas as pd 
import numpy  as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Data/user_hits_binning_import.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userid  12 non-null     int64
#  1   date    12 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 320.0+ bytes

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['valeur']=np.random.choice(range(100),12,replace=True)

# %%
df.plot(x='date',y='valeur')
# Out:
# <AxesSubplot: xlabel='date'>

# %%
#print(df.head(to_markdown()))
